# %% [markdown]
# <a href="https://colab.research.google.com/github/hayannn/AIFFEL_MAIN_QUEST/blob/main/FDSPreFunction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 신용거래 이상탐지 데이터 Code Function
# - 함수 통합!

# %%
import pandas as pd
import numpy as np
import sys

# %%
sys.path.append('/content/drive/MyDrive/Colab Notebooks/FDS_1104/src')

# %%
fraud_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/FDS_1104/fraud.csv')
columns_to_drop = ['is_fraud']
fraud_df = fraud_df.drop(columns_to_drop, axis=1)

# %% [markdown]
# - 모든 function 통합 과정 진행

# %%
from drop_func_before_feature_engineering import drop_func_before_feature_engineering
from outlier_func import outlier_func
from nf_func_trans_time import nf_func_trans_time
from nf_func_distance import nf_func_distance
from nf_func_trans_count import nf_func_trans_count
from onehot_func import onehot_func
from nf_func_amt_per_citypop import nf_func_amt_per_citypop
from nf_func_amt_ratio import nf_func_amt_ratio
from nf_func_age import nf_func_age
from drop_func_after_feature_engineering import drop_func_after_feature_engineering
from rename_cols_func import rename_cols_func

def pre_func(data):
  data = drop_func_before_feature_engineering(data)
  data = outlier_func(data)
  data = nf_func_trans_time(data)
  data = nf_func_distance(data)
  data = nf_func_trans_count(data)
  data = onehot_func(data)
  data = nf_func_amt_per_citypop(data)
  data = nf_func_amt_ratio(data)
  data = nf_func_age(data)
  data = drop_func_after_feature_engineering(data)
  data = rename_cols_func(data)

  return data

# %% [markdown]
# - 파일로 저장하기

# %%
script = """
from drop_func_before_feature_engineering import drop_func_before_feature_engineering
from outlier_func import outlier_func
from nf_func_trans_time import nf_func_trans_time
from nf_func_distance import nf_func_distance
from nf_func_trans_count import nf_func_trans_count
from onehot_func import onehot_func
from nf_func_amt_per_citypop import nf_func_amt_per_citypop
from nf_func_amt_ratio import nf_func_amt_ratio
from nf_func_age import nf_func_age
from drop_func_after_feature_engineering import drop_func_after_feature_engineering
from rename_cols_func import rename_cols_func

def pre_func(data):
  data = drop_func_before_feature_engineering(data)
  data = outlier_func(data)
  data = nf_func_trans_time(data)
  data = nf_func_distance(data)
  data = nf_func_trans_count(data)
  data = onehot_func(data)
  data = nf_func_amt_per_citypop(data)
  data = nf_func_amt_ratio(data)
  data = nf_func_age(data)
  data = drop_func_after_feature_engineering(data)
  data = rename_cols_func(data)

  return data
"""

# %%
filename = '/content/drive/MyDrive/Colab Notebooks/FDS_1104/src/pre_func.py'

with open(filename, 'w') as file:
    file.write(script)

# %% [markdown]
# - 최종 테스트(이 노트북에서는 코드만 업로드, 다른 노트북에서 실행함!)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
import sys
import pandas as pd

sys.path.append('/content/drive/MyDrive/Colab Notebooks/FDS_1104/src')
fraud_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/FDS_1104/fraud.csv')

from pre_func import pre_func
fraud_df pre_func(fraud_df)

fraud_df.head()
